# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd
#import io
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Find the dimension of given data

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# List down all the columns in data frame

# %%
list(df)
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %% [markdown]
# List the top 10 rows in datframe

# %%
df.head(10)
# Out:
#    Company   Age  Salary     Place Country
# 0      TCS  20.0     NaN   Chennai   India
# 1  Infosys  30.0     NaN    Mumbai   India
# 2      TCS  35.0  2300.0  Calcutta   India
# 3  Infosys  40.0  3000.0     Delhi   India
# 4      TCS  23.0  4000.0    Mumbai   India
# 5  Infosys   NaN  5000.0  Calcutta   India
# 6      TCS   NaN  6000.0   Chennai   India
# 7  Infosys  23.0  7000.0    Mumbai   India
# 8      TCS  34.0  8000.0  Calcutta   India
# 9      CTS  45.0  9000.0     Delhi   India

# %% [markdown]
# List the last 15 rows in datframe

# %%
df.tail(15)
# Out:
#                        Company   Age  Salary      Place Country
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India
# 135                        CTS  40.0  9284.0   Calcutta   India
# 136                        NaN   NaN     NaN      Delhi   India
# 137                        CTS  31.0  2034.0     Mumbai   India
# 138                        CTS  44.0  3033.0     Cochin   India
# 139                 Congnizant  22.0  2934.0      Noida   India
# 140                    Infosys  44.0  4034.0  Hyderabad   India
# 141                        TCS  33.0  5034.0   Calcutta   India
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India
# 143                        TCS  33.0  9024.0   Calcutta   India
# 144                    Infosys  22.0  8787.0   Calcutta   India
# 145                    Infosys  44.0  4034.0      Delhi   India
# 146                        TCS  33.0  5034.0     Mumbai   India
# 147                    Infosys  22.0  8202.0     Cochin   India
# 148                        NaN   NaN     NaN        NaN     NaN

# %% [markdown]
# Find the number of rows in dataframe

# %%
df.shape[0]
# Out:
# 149

# %%
df.count()
# Out:
# Company    140
# Age        130
# Salary     124
# Place      134
# Country    148
# dtype: int64

# %%
df.Age.mean()
# Out:
# 30.484615384615385

# %% [markdown]
# Check the information of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 5.9+ KB

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
df[['Salary','Age']].describe()
# Out:
#             Salary         Age
# count   124.000000  130.000000
# mean   5312.467742   30.484615
# std    2573.764683   11.096640
# min    1089.000000    0.000000
# 25%    3030.000000   22.000000
# 50%    5000.000000   32.500000
# 75%    8000.000000   37.750000
# max    9876.000000   54.000000

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
df.iloc[20:101,:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
lis = []
df.loc[20:100,['Company','Salary']]
# Out:
#      Company  Salary
# 20       TCS  3045.0
# 21   Infosys  3184.0
# 22       TCS  4824.0
# 23   Infosys  5835.0
# 24       TCS  7084.0
# ..       ...     ...
# 96       TCS  7084.0
# 97   Infosys  8943.0
# 98       TCS  8345.0
# 99       CTS  9284.0
# 100      CTS     NaN
#
# [81 rows x 2 columns]

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
df
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %%
df.at[100,'Place']  = 'Noida'
df.iloc[100]
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place      Noida
# Country    India
# Name: 100, dtype: object

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
df.rename(columns={'City':'Place'},inplace=True)

# %%
df.rename(columns = {'Place':'City','Country':'States'}, inplace = True)

# %%
print(df)
# Out:
#      Company   Age  Salary      City States
# 0        TCS  20.0     NaN   Chennai  India
# 1    Infosys  30.0     NaN    Mumbai  India
# 2        TCS  35.0  2300.0  Calcutta  India
# 3    Infosys  40.0  3000.0     Delhi  India
# 4        TCS  23.0  4000.0    Mumbai  India
# ..       ...   ...     ...       ...    ...
# 144  Infosys  22.0  8787.0  Calcutta  India
# 145  Infosys  44.0  4034.0     Delhi  India
# 146      TCS  33.0  5034.0    Mumbai  India
# 147  Infosys  22.0  8202.0    Cochin  India
# 148      NaN   NaN     NaN       NaN    NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
df.nunique(axis=0)
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# States      1
# dtype: int64

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
df.loc[(df.Company.isin(['CTS','TCS','Infosys']))]
# Out:
#      Company   Age  Salary      City States
# 0        TCS  20.0     NaN   Chennai  India
# 1    Infosys  30.0     NaN    Mumbai  India
# 2        TCS  35.0  2300.0  Calcutta  India
# 3    Infosys  40.0  3000.0     Delhi  India
# 4        TCS  23.0  4000.0    Mumbai  India
# ..       ...   ...     ...       ...    ...
# 143      TCS  33.0  9024.0  Calcutta  India
# 144  Infosys  22.0  8787.0  Calcutta  India
# 145  Infosys  44.0  4034.0     Delhi  India
# 146      TCS  33.0  5034.0    Mumbai  India
# 147  Infosys  22.0  8202.0    Cochin  India
#
# [134 rows x 5 columns]

# %%
#Where ever you see age as 0 replace with NA

##Hint df[df.Age==20] = np.isnan

# %%
import numpy as np
df[df.Age == 0] = np.isnan
df[df.Age == 0]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, States]
# Index: []

# %%
df['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148     True
# Name: Age, Length: 149, dtype: bool

# %% [markdown]
# Check how many duplicated data is there?

# %%
df.duplicated().sum()
# Out:
# 13

# %% [markdown]
# Remove all duplicated rowise data

# %%
df.drop_duplicates()
# Out:
#              Company   Age  Salary       City States
# 0                TCS  20.0     NaN    Chennai  India
# 1            Infosys  30.0     NaN     Mumbai  India
# 2                TCS  35.0  2300.0   Calcutta  India
# 3            Infosys  40.0  3000.0      Delhi  India
# 4                TCS  23.0  4000.0     Mumbai  India
# ..               ...   ...     ...        ...    ...
# 140          Infosys  44.0  4034.0  Hyderabad  India
# 141              TCS  33.0  5034.0   Calcutta  India
# 142  Infosys Pvt Lmt  22.0  8202.0     Mumbai  India
# 143              TCS  33.0  9024.0   Calcutta  India
# 148              NaN   NaN     NaN        NaN    NaN
#
# [136 rows x 5 columns]

# %% [markdown]
# Remove the column 'Country'

# %% [markdown]
# Remove the row number 137

# %% [markdown]
# Find number of each labels in Company

# %%
df.Company.value_counts()
# Out:
# TCS                          51
# Infosys                      43
# CTS                          34
# <ufunc 'isnan'>               6
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
df.City.value_counts()
# Out:
# Mumbai             36
# Calcutta           31
# Chennai            13
# Delhi              13
# Cochin             12
# Noida               9
# Hyderabad           8
# <ufunc 'isnan'>     6
# Podicherry          2
# Pune                2
# Bhopal              1
# Nagpur              1
# Name: City, dtype: int64

# %% [markdown]
# Find Number of Null Values in each column

# %%
df.isna().sum()
# Out:
# Company     9
# Age        19
# Salary     25
# City       15
# States      1
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
df.dropna(subset=['Salary'])
# Out:
#      Company   Age  Salary      City States
# 2        TCS  35.0  2300.0  Calcutta  India
# 3    Infosys  40.0  3000.0     Delhi  India
# 4        TCS  23.0  4000.0    Mumbai  India
# 5    Infosys   NaN  5000.0  Calcutta  India
# 6        TCS   NaN  6000.0   Chennai  India
# ..       ...   ...     ...       ...    ...
# 143      TCS  33.0  9024.0  Calcutta  India
# 144  Infosys  22.0  8787.0  Calcutta  India
# 145  Infosys  44.0  4034.0     Delhi  India
# 146      TCS  33.0  5034.0    Mumbai  India
# 147  Infosys  22.0  8202.0    Cochin  India
#
# [124 rows x 5 columns]

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
df.Company.fillna(df.Company.mode()[0])
df
# Out:
#      Company   Age  Salary      City States
# 0        TCS  20.0     NaN   Chennai  India
# 1    Infosys  30.0     NaN    Mumbai  India
# 2        TCS  35.0  2300.0  Calcutta  India
# 3    Infosys  40.0  3000.0     Delhi  India
# 4        TCS  23.0  4000.0    Mumbai  India
# ..       ...   ...     ...       ...    ...
# 144  Infosys  22.0  8787.0  Calcutta  India
# 145  Infosys  44.0  4034.0     Delhi  India
# 146      TCS  33.0  5034.0    Mumbai  India
# 147  Infosys  22.0  8202.0    Cochin  India
# 148      NaN   NaN     NaN       NaN    NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Replace the null value in Salary with median

# %%
df[df.Salary == np.isnan]
# Out:
#              Company              Age           Salary             City  \
# 88   <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
# 92   <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
# 101  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
# 107  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
# 111  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
# 121  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>  <ufunc 'isnan'>
#
#               States
# 88   <ufunc 'isnan'>
# 92   <ufunc 'isnan'>
# 101  <ufunc 'isnan'>
# 107  <ufunc 'isnan'>
# 111  <ufunc 'isnan'>
# 121  <ufunc 'isnan'>

# %%
df.Salary.fillna(df.Salary.mode()[0])
# Out:
# 0      3000.0
# 1      3000.0
# 2      2300.0
# 3      3000.0
# 4      4000.0
#         ...
# 144    8787.0
# 145    4034.0
# 146    5034.0
# 147    8202.0
# 148    3000.0
# Name: Salary, Length: 149, dtype: object

# %% [markdown]
# Replace the null value in age with mean

# %%
df.Age.fillna(df['Age'])
df
# Out:
#      Company   Age  Salary      City States
# 0        TCS  20.0     NaN   Chennai  India
# 1    Infosys  30.0     NaN    Mumbai  India
# 2        TCS  35.0  2300.0  Calcutta  India
# 3    Infosys  40.0  3000.0     Delhi  India
# 4        TCS  23.0  4000.0    Mumbai  India
# ..       ...   ...     ...       ...    ...
# 144  Infosys  22.0  8787.0  Calcutta  India
# 145  Infosys  44.0  4034.0     Delhi  India
# 146      TCS  33.0  5034.0    Mumbai  India
# 147  Infosys  22.0  8202.0    Cochin  India
# 148      NaN   NaN     NaN       NaN    NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
df
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Draw the pie chart for place and Company

# %%
import matplotlib.pyplot as plt
df.groupby(['Place','Company']).sum().plot(kind='pie', subplots=True, figsize=(30, 50),autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Find the mean age with repective to the Company

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                    'Max Speed': [380., 370., 24., 26.]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
aa = df.groupby('Company')[['Salary','Age']].mean()
#bb = df.groupby('Company')['Age'].mean()
print(aa.astype('int64'))
print(aa,end="\n\n")
# Out:
#                            Salary  Age
# Company
# CTS                          4714   32
# Congnizant                   2934   21
# Infosys                      5191   32
# Infosys Pvt Lmt              8202   21
# TCS                          5493   28
# Tata Consultancy Services    8345   33
#                                 Salary        Age
# Company
# CTS                        4714.840000  32.194444
# Congnizant                 2934.000000  21.500000
# Infosys                    5191.317073  32.621622
# Infosys Pvt Lmt            8202.000000  21.500000
# TCS                        5493.319149  28.444444
# Tata Consultancy Services  8345.000000  33.500000

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %% [markdown]
# Draw an histogram chart for age, Salary

# %%
df.hist(['Age','Salary'])
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
df.groupby(['Place']).Salary.mean().astype('int32')
# Out:
# Place
# Bhopal        7000
# Calcutta      5033
# Chennai       6115
# Cochin        5053
# Delhi         4768
# Hyderabad     4382
# Mumbai        4867
# Nagpur        8000
# Noida         4387
# Podicherry    4782
# Pune          9000
# Name: Salary, dtype: int32

# %%
df.groupby(['Place']).Salary.median()
# Out:
# Place
# Bhopal        7000.0
# Calcutta      4584.5
# Chennai       6000.0
# Cochin        5017.0
# Delhi         3609.0
# Hyderabad     3609.0
# Mumbai        4824.0
# Nagpur        8000.0
# Noida         4000.0
# Podicherry    3030.0
# Pune          9000.0
# Name: Salary, dtype: float64

# %%
df.groupby(['Place']).Salary.value_counts()
# Out:
# Place       Salary
# Bhopal      7000.0    1
# Calcutta    8787.0    3
#             1234.0    2
#             2300.0    2
#             3030.0    2
#                      ..
# Noida       8000.0    1
# Podicherry  2034.0    1
#             3030.0    1
#             9284.0    1
# Pune        9000.0    1
# Name: Salary, Length: 94, dtype: int64
